# %%
import re
import string
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')

# %%
train.shape
# Out:
# (31962, 3)

# %%
train.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %% [markdown]
# Exploratory Data Analysis

# %%
train['label'].value_counts()
# Out:
# 0    29720
# 1     2242
# Name: label, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='label',data=train)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ramanjaneyareddy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def transform_text(text):
    text = text.lower()
    
    r = re.findall('@[\w]*', text)
    
    for w in r:
        text = text.replace(w, ' ')
    text = text.replace('[^a-zA-Z#]', '')
    text = ' '.join([word for word in text.split() if len(word) > 3])
    
    text = re.sub(r'\$%,.\:\?', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    
    words = text.split(" ")
    words = [lemma.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    text = ' '.join(words) 
    
    return text

# %%
train['clean_text'] = train['tweet'].apply(lambda x : transform_text(x))

# %%
train.sample(5)
# Out:
#           id  label                                              tweet  \
# 6358    6359      0  feliz tarde!   #toptags days top.tags day #smi...
# 10120  10121      0  you're #1 for a reason @user you made fav #pob...
# 30276  30277      0  well back at third shift again, but mr and my ...
# 30046  30047      0    four tet isn't happy with soundcloud: after ...
# 9266    9267      0  live on #periscope: only 35mins til the jumpst...
#
#                                               clean_text
# 6358   feliz tarde! #toptags day top.tags #smile #fun...
# 10120  reason made #poboy hubby even menu today #yegfood
# 30276  well back third shift again, girl hitting tomo...
# 30046  four happy soundcloud: reaching million follow...
# 9266   live #periscope: 35mins jumpsta workshop! #amw...

# %%
# Visualizing all words

all_words = " ".join(sent for sent in train['clean_text'])

from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(all_words)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Frequency of Positive Words

pos_words = " ".join(sent for sent in train['clean_text'][train['label'] == 0])

wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(pos_words)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Frequency of Negative Words

neg_words = " ".join(sent for sent in train['clean_text'][train['label'] == 1])

wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(neg_words)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Extract Hashtags

def extract_hashtag(texts):
    hash = []
    
    for text in texts:
        ht = re.findall(r"#(\w+)", text)
        hash.append(ht)
        
    return hash

# %%
hash_pos = extract_hashtag(train['clean_text'][train['label'] == 0])

# %%
hash_neg = extract_hashtag(train['clean_text'][train['label'] == 1])

# %%
hash_neg[:10]
# Out:
# [['cnn', 'michigan', 'tcot'],
#  ['australia',
#   'opkillingbay',
#   'seashepherd',
#   'helpcovedolphins',
#   'thecove',
#   'helpcovedolphins'],
#  [],
#  [],
#  ['neverump', 'xenophobia'],
#  ['love', 'peace'],
#  [],
#  ['race', 'identity', 'medâ'],
#  ['altright', 'whitesupremacy'],
#  ['linguistics', 'race', 'power', 'raciolinguistics']]

# %%
# unnest list
hash_pos = sum(hash_pos, [])
hash_neg = sum(hash_neg, [])

# %%
hash_pos[:10]
# Out:
# ['run',
#  'lyft',
#  'disapointed',
#  'getthanked',
#  'model',
#  'motivation',
#  'allshowandnogo',
#  'school',
#  'exams',
#  'hate']

# %%
freq = nltk.FreqDist(hash_pos)
pos = pd.DataFrame({'Hashtag': list(freq.keys()),
                 'Count': list(freq.values())})
pos.head()
# Out:
#        Hashtag  Count
# 0          run     33
# 1         lyft      2
# 2  disapointed      1
# 3   getthanked      2
# 4        model    364

# %%
# select top 10 hashtags
pos = pos.nlargest(columns='Count', n=10)
plt.figure(figsize=(15,8))
sns.barplot(data=pos, x='Hashtag', y='Count')
plt.show()

# %%
freq = nltk.FreqDist(hash_neg)
neg = pd.DataFrame({'Hashtag': list(freq.keys()),
                 'Count': list(freq.values())})
neg.head()
# Out:
#         Hashtag  Count
# 0           cnn      9
# 1      michigan      2
# 2          tcot     14
# 3     australia      6
# 4  opkillingbay      2

# %%
# select top 10 hashtags
neg = neg.nlargest(columns='Count', n=10)
plt.figure(figsize=(15,8))
sns.barplot(data=neg, x='Hashtag', y='Count')
plt.show()

# %%
# feature extraction
from sklearn.feature_extraction.text import CountVectorizer
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
bow = bow_vectorizer.fit_transform(train['clean_text'])

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(bow, train['label'], random_state=42, test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score

# %%
# training
model = LogisticRegression()
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
# testing
pred = model.predict(xtest)
f1_score(ytest, pred)
# Out:
# 0.4835965978128798

# %%
accuracy_score(ytest,pred)
# Out:
# 0.9468151670629458

# %%
# use probability to get output
pred_prob = model.predict_proba(xtest)
pred = pred_prob[:, 1] >= 0.3
pred = pred.astype(np.int)

f1_score(ytest, pred)
# Out:
# 0.532520325203252

# %%
accuracy_score(ytest,pred)
# Out:
# 0.9424352396446002
